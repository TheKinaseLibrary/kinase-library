# %% [markdown]
# # The Kinase Library

# %%
import kinase_library as kl

# %% [markdown]
# ## Kinase object

# %% [markdown]
# A de-novo Kinase object get be initiated using a matrix, or simply by calling an existing kinase from the library

# %%
kin = kl.get_kinase('AKT1')

# %% [markdown]
# Kinase object contains information about the retrieved kinase:

# %%
print('Name: ' + kin.name)
print('\nMatrix:')
print(kin.log2_matrix)
print('\nKinase type: ' + kin.kin_type)
print('\nKinase family: ' + kin.family)
# Out:
# Name: AKT1
#
# Matrix:
#        -5      -4      -3      -2      -1       1       2       3       4
# P  0.0363 -0.1358 -0.9807 -1.7226  0.0554 -1.4750 -0.4489 -0.2636  0.6474
# G  0.0130  0.0486 -1.1430 -0.7561  0.4053 -0.6050  0.1014  0.2744  0.0163
# A -0.0921 -0.1610 -0.8802 -0.0861 -0.4374 -1.0227 -0.1398 -0.2626 -0.2695
# C  0.0411 -0.2455 -0.9227  0.0696 -0.4298  0.0000  0.3321  0.1530 -0.2758
# S -0.1887 -0.1610 -1.5081 -1.0046  0.0155 -0.1140 -0.1308 -0.0548 -0.2695
# T -0.1887 -0.1610 -1.5081 -1.0046  0.0155 -0.1140 -0.1308 -0.0548 -0.2695
# V -0.4607 -0.4017 -2.0711 -1.1839 -1.1548  0.4837  0.1445 -0.3556 -0.5115
# I -0.4350 -0.5996 -2.0285 -1.2736 -1.5710  0.7650  0.0268 -0.2550 -0.6299
# L -0.3419 -0.4155 -1.7592  0.0308 -0.0323  0.2908  0.1792 -0.2764 -0.3479
# M -0.2195 -0.1526 -1.8281 -1.0046  0.1795  0.7578 -0.3446 -0.2534 -0.3721
# F -0.1059 -0.4456 -1.8840 -0.9876 -0.2651  1.2105 -0.3967  0.0470 -0.5958
# Y -0.1887 -0.3497 -1.4935 -1.3501  0.3109 -0.2294 -0.1308 -0.0301 -0.7550
# W -0.1628 -0.0411 -1.5081 -1.5923 -0.5932  0.1689 -0.2666 -0.0548 -0.1774
# H  0.1500  0.0277 -0.2571 -0.2541  0.2360 -0.3375  0.6442  0.3840  0.1728
# K  0.6910  0.8859  1.2215  1.1258  0.8319 -0.2284  0.3791  0.6430  0.9604
# R  1.3679  1.4603  3.1810  2.8630  0.8067 -0.0708  0.9626  0.9541  0.8792
# Q -0.2595 -0.1358 -0.8364 -0.8739  0.0155  0.1105 -0.1463 -0.0527  0.3206
# N -0.3315 -0.3142 -1.5899 -1.1705  0.5223 -0.1140  0.1137  0.0853  0.1424
# D -0.6462 -0.8179 -2.5994 -2.8088 -0.4620 -1.7640 -0.8692 -1.0032 -0.4102
# E -0.6459 -0.5082 -2.6094 -2.9178 -1.3716 -1.7743 -1.3449 -0.8977 -0.9147
# s -0.4662 -0.3822 -1.6339 -1.5239 -1.7299 -1.1365 -1.0215 -0.8045 -0.5825
# t -0.4662 -0.3822 -1.6339 -1.5239 -1.7299 -1.1365 -1.0215 -0.8045 -0.5825
# y -0.4581 -0.5303 -1.7432 -1.8722 -0.1525 -0.7995 -0.6315 -0.7927 -1.1623
#
# Kinase type: ser_thr
#
# Kinase family: AGC

# %%
kin.info
# Out:
# 'N/A'

# %% [markdown]
# Plot kinase ID (sequence logo, heatmat, and  S/T favorability):

# %%
kin.plot_data()

# %%
kin.plot_data(title='My Favorite Kinase')

# %% [markdown]
# Sequence logo can be plotted separately with different configurations

# %%
kin.seq_logo(logo_type='prob') #can be 'ratio_to_random', 'ratio_to_median', or 'prob'

# %% [markdown]
# As well as heatmap

# %%
kin.heatmap()

# %% [markdown]
# Kinase object can be used to quickly score a list of substrates

# %%
subs_list = ['VDDEKGDsNDDYDSA',
 'YDSAGLLsDEDCMSV',
 'IADHLFWtEETKSRF',
 'KSRFTEYsMTSSVMR',
 'FTEYSMTsSVMRRNE',
 'TEYSMTSsVMRRNEQ',
 'MCQGGDFtRPNGTGD',
 'MGGRKMAtDEENVYG',
 'ATDEENVsGLEENAQ',
 'FQRGKYGtMAEGRSE']

kin.score(subs_list)
# Out:
# VDDEKGDsNDDYDSA   -3.89
# YDSAGLLsDEDCMSV   -5.88
# IADHLFWtEETKSRF   -6.17
# KSRFTEYsMTSSVMR   -2.89
# FTEYSMTsSVMRRNE   -2.84
# TEYSMTSsVMRRNEQ   -1.19
# MCQGGDFtRPNGTGD   -4.85
# MGGRKMAtDEENVYG   -2.61
# ATDEENVsGLEENAQ   -8.33
# FQRGKYGtMAEGRSE    1.43
# Name: AKT1, dtype: float64

# %%
kin.percentile(subs_list)
# Out:
# VDDEKGDsNDDYDSA    38.94
# YDSAGLLsDEDCMSV    13.66
# IADHLFWtEETKSRF    11.33
# KSRFTEYsMTSSVMR    54.32
# FTEYSMTsSVMRRNE    55.11
# TEYSMTSsVMRRNEQ    74.59
# MCQGGDFtRPNGTGD    24.90
# MGGRKMAtDEENVYG    58.44
# ATDEENVsGLEENAQ     2.07
# FQRGKYGtMAEGRSE    90.64
# Name: AKT1, dtype: float64
